# %%
from PIL import Image
import matplotlib.pyplot as plt
from utils import draw_detections_v2
from utils import run_detection_v2


# 예시 이미지 불러오기
image = Image.open("/home/user/AI-server/AI_detection_server/uploads/unnamed.jpg")

image = Image.open("/home/user/AI-server/AI_detection_server/uploads/unnamed.jpg")  # PIL 이미지 로드
detections = run_detection_v2(image)  # YOLO 모델 추론
result_img = draw_detections_v2(image, detections)  # 박스+라벨 그림

result_img.show()
# Out:
# 0: 448x640 2 crowns, 34.9ms
# Speed: 8.6ms preprocess, 34.9ms inference, 12.4ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=512x340>

# %%
# !pip install celery
# Out:
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
